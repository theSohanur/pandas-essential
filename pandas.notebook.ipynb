# %%
import pandas as pd

# %%
pd.show_versions()
# Out:
# INSTALLED VERSIONS
# ------------------
# commit           : db08276bc116c438d3fdee492026f8223584c477
# python           : 3.8.5.final.0
# python-bits      : 64
# OS               : Windows
# OS-release       : 10
# Version          : 10.0.19041
# machine          : AMD64
# processor        : Intel64 Family 6 Model 58 Stepping 9, GenuineIntel
# byteorder        : little
# LC_ALL           : None
# LANG             : None
# LOCALE           : English_United States.1252
#
# pandas           : 1.1.3
# numpy            : 1.19.2
# pytz             : 2020.1
# dateutil         : 2.8.1
# pip              : 20.2.4
# setuptools       : 50.3.1.post20201107
# Cython           : 0.29.21
# pytest           : 6.1.1
# hypothesis       : None
# sphinx           : 3.2.1
# blosc            : None
# feather          : None
# xlsxwriter       : 1.3.7
# lxml.etree       : 4.6.1
# html5lib         : 1.1
# pymysql          : None
# psycopg2         : None
# jinja2           : 2.11.2
# ...

# %%
pd.__version__
# Out:
# '1.1.3'

# %%
pd.show_versions
# Out:
# <function pandas.util._print_versions.show_versions(as_json: Union[str, bool] = False) -> None>

# %%
clear

# %%
pd.show_versions()
# Out:
# INSTALLED VERSIONS
# ------------------
# commit           : db08276bc116c438d3fdee492026f8223584c477
# python           : 3.8.5.final.0
# python-bits      : 64
# OS               : Windows
# OS-release       : 10
# Version          : 10.0.19041
# machine          : AMD64
# processor        : Intel64 Family 6 Model 58 Stepping 9, GenuineIntel
# byteorder        : little
# LC_ALL           : None
# LANG             : None
# LOCALE           : English_United States.1252
#
# pandas           : 1.1.3
# numpy            : 1.19.2
# pytz             : 2020.1
# dateutil         : 2.8.1
# pip              : 20.2.4
# setuptools       : 50.3.1.post20201107
# Cython           : 0.29.21
# pytest           : 6.1.1
# hypothesis       : None
# sphinx           : 3.2.1
# blosc            : None
# feather          : None
# xlsxwriter       : 1.3.7
# lxml.etree       : 4.6.1
# html5lib         : 1.1
# pymysql          : None
# psycopg2         : None
# jinja2           : 2.11.2
# ...

# %%
pd.__version__
# Out:
# '1.1.3'

# %%
# Markdown in Jupyter Notebook 
# https://www.datacamp.com/community/tutorials/markdown-in-jupyter-notebook

# %%
pd.read_csv('./data/olympics.csv')
# Out:
#       List of medallists at the Games of the Olympiad per edition, sport, discipline, gender and event  \
# 0                                                    NaN
# 1      DISCLAIMER: The IOC Research and Reference Ser...
# 2                                                    NaN
# 3                                                   City
# 4                                                 Athens
# ...                                                  ...
# 29215                                            Beijing
# 29216                                            Beijing
# 29217                                            Beijing
# 29218                                            Beijing
# 29219                                            Beijing
#
#       Unnamed: 1 Unnamed: 2       Unnamed: 3            Unnamed: 4 Unnamed: 5  \
# 0            NaN        NaN              NaN                   NaN        NaN
# ...

# %%
oly = pd.read_csv('./data/olympics.csv',skiprows=4)

# %%
#Export Data csv to excel
oly.to_excel("ole.xlsx")

# %%
#Discribe Data
oly.dtypes
# Out:
# Athlete         object
# City            object
# Edition          int64
# Sport           object
# Discipline      object
# NOC             object
# Gender          object
# Event           object
# Event_gender    object
# Medal           object
# dtype: object

# %%
#Check columns and store in a list
oly_columns = oly.columns
oly_columns
# Out:
# Index(['Athlete', 'City', 'Edition', 'Sport', 'Discipline', 'NOC', 'Gender',
#        'Event', 'Event_gender', 'Medal'],
#       dtype='object')

# %%
oly.head(10)
# Out:
#      City  Edition     Sport Discipline                Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming          HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming       HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming      DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming     MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming     CHASAPIS, Spiridon  GRE    Men
# 5  Athens     1896  Aquatics   Swimming  CHOROPHAS, Efstathios  GRE    Men
# 6  Athens     1896  Aquatics   Swimming          HAJOS, Alfred  HUN    Men
# 7  Athens     1896  Aquatics   Swimming       ANDREOU, Joannis  GRE    Men
# 8  Athens     1896  Aquatics   Swimming  CHOROPHAS, Efstathios  GRE    Men
# 9  Athens     1896  Aquatics   Swimming          NEUMANN, Paul  AUT    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# ...

# %%
oly.tail(5)
# Out:
#           City  Edition      Sport       Discipline               Athlete  \
# 29211  Beijing     2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko
# 29212  Beijing     2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas
# 29213  Beijing     2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain
# 29215  Beijing     2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan
#
#        NOC Gender       Event Event_gender   Medal
# 29211  GER    Men   84 - 96kg            M  Silver
# 29212  LTU    Men  96 - 120kg            M  Bronze
# 29213  ARM    Men  96 - 120kg            M  Bronze
# 29214  CUB    Men  96 - 120kg            M    Gold
# 29215  RUS    Men  96 - 120kg            M  Silver

# %% [markdown]
# # Accessing Series

# %%
oly['City']
# Out:
# 0         Athens
# 1         Athens
# 2         Athens
# 3         Athens
# 4         Athens
#           ...
# 29211    Beijing
# 29212    Beijing
# 29213    Beijing
# 29214    Beijing
# 29215    Beijing
# Name: City, Length: 29216, dtype: object

# %%
oo = pd.read_csv('./data/Summer Olympic medallists 1896 to 2008 - IOC COUNTRY CODES.csv')

# %%
oo
# Out:
#              Country Int Olympic Committee code ISO code        Country.1
# 0        Afghanistan                        AFG       AF      Afghanistan
# 1            Albania                        ALB       AL          Albania
# 2            Algeria                        ALG       DZ          Algeria
# 3    American Samoa*                        ASA       AS  American Samoa*
# 4            Andorra                        AND       AD          Andorra
# ..               ...                        ...      ...              ...
# 196          Vietnam                        VIE       VN          Vietnam
# 197  Virgin Islands*                        ISV       VI  Virgin Islands*
# 198            Yemen                        YEM       YE            Yemen
# 199           Zambia                        ZAM       ZM           Zambia
# 200         Zimbabwe                        ZIM       ZW         Zimbabwe
#
# [201 rows x 4 columns]

# %%
oo['Country']
# Out:
# 0          Afghanistan
# 1              Albania
# 2              Algeria
# 3      American Samoa*
# 4              Andorra
#             ...
# 196            Vietnam
# 197    Virgin Islands*
# 198              Yemen
# 199             Zambia
# 200           Zimbabwe
# Name: Country, Length: 201, dtype: object

# %%
oly.Athlete
# Out:
# 0               HAJOS, Alfred
# 1            HERSCHMANN, Otto
# 2           DRIVAS, Dimitrios
# 3          MALOKINIS, Ioannis
# 4          CHASAPIS, Spiridon
#                  ...
# 29211          ENGLICH, Mirko
# 29212    MIZGAITIS, Mindaugas
# 29213         PATRIKEEV, Yuri
# 29214           LOPEZ, Mijain
# 29215          BAROEV, Khasan
# Name: Athlete, Length: 29216, dtype: object

# %%
oly["Athlete"]
# Out:
# 0               HAJOS, Alfred
# 1            HERSCHMANN, Otto
# 2           DRIVAS, Dimitrios
# 3          MALOKINIS, Ioannis
# 4          CHASAPIS, Spiridon
#                  ...
# 29211          ENGLICH, Mirko
# 29212    MIZGAITIS, Mindaugas
# 29213         PATRIKEEV, Yuri
# 29214           LOPEZ, Mijain
# 29215          BAROEV, Khasan
# Name: Athlete, Length: 29216, dtype: object

# %% [markdown]
# # Accessing Multiple series

# %%
oly[["City","Athlete"]]
# Out:
#           City               Athlete
# 0       Athens         HAJOS, Alfred
# 1       Athens      HERSCHMANN, Otto
# 2       Athens     DRIVAS, Dimitrios
# 3       Athens    MALOKINIS, Ioannis
# 4       Athens    CHASAPIS, Spiridon
# ...        ...                   ...
# 29211  Beijing        ENGLICH, Mirko
# 29212  Beijing  MIZGAITIS, Mindaugas
# 29213  Beijing       PATRIKEEV, Yuri
# 29214  Beijing         LOPEZ, Mijain
# 29215  Beijing        BAROEV, Khasan
#
# [29216 rows x 2 columns]

# %%
oly[["City","Athlete","Gender",'Medal']].head(10)
# Out:
#      City                Athlete Gender   Medal
# 0  Athens          HAJOS, Alfred    Men    Gold
# 1  Athens       HERSCHMANN, Otto    Men  Silver
# 2  Athens      DRIVAS, Dimitrios    Men  Bronze
# 3  Athens     MALOKINIS, Ioannis    Men    Gold
# 4  Athens     CHASAPIS, Spiridon    Men  Silver
# 5  Athens  CHOROPHAS, Efstathios    Men  Bronze
# 6  Athens          HAJOS, Alfred    Men    Gold
# 7  Athens       ANDREOU, Joannis    Men  Silver
# 8  Athens  CHOROPHAS, Efstathios    Men  Bronze
# 9  Athens          NEUMANN, Paul    Men    Gold

# %%
type(oly)
# Out:
# pandas.core.frame.DataFrame

# %%
type(oly.City)
# Out:
# pandas.core.series.Series

# %%
type(oly[["City","Athlete","Gender",'Medal']])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # Chalange Chapter 2

# %%
oly
# Out:
#           City  Edition      Sport       Discipline               Athlete  \
# 0       Athens     1896   Aquatics         Swimming         HAJOS, Alfred
# 1       Athens     1896   Aquatics         Swimming      HERSCHMANN, Otto
# 2       Athens     1896   Aquatics         Swimming     DRIVAS, Dimitrios
# 3       Athens     1896   Aquatics         Swimming    MALOKINIS, Ioannis
# 4       Athens     1896   Aquatics         Swimming    CHASAPIS, Spiridon
# ...        ...      ...        ...              ...                   ...
# 29211  Beijing     2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko
# 29212  Beijing     2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas
# 29213  Beijing     2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain
# 29215  Beijing     2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan
#
#        NOC Gender                       Event Event_gender   Medal
# ...

# %%
oly['NOC']
# Out:
# 0        HUN
# 1        AUT
# 2        GRE
# 3        GRE
# 4        GRE
#         ...
# 29211    GER
# 29212    LTU
# 29213    ARM
# 29214    CUB
# 29215    RUS
# Name: NOC, Length: 29216, dtype: object

# %%
oly.NOC
# Out:
# 0        HUN
# 1        AUT
# 2        GRE
# 3        GRE
# 4        GRE
#         ...
# 29211    GER
# 29212    LTU
# 29213    ARM
# 29214    CUB
# 29215    RUS
# Name: NOC, Length: 29216, dtype: object

# %%
type(oly.NOC)
# Out:
# pandas.core.series.Series

# %%
type(oly)
# Out:
# pandas.core.frame.DataFrame

# %%
oly[['Edition','City','Athlete']]
# Out:
#        Edition     City               Athlete
# 0         1896   Athens         HAJOS, Alfred
# 1         1896   Athens      HERSCHMANN, Otto
# 2         1896   Athens     DRIVAS, Dimitrios
# 3         1896   Athens    MALOKINIS, Ioannis
# 4         1896   Athens    CHASAPIS, Spiridon
# ...        ...      ...                   ...
# 29211     2008  Beijing        ENGLICH, Mirko
# 29212     2008  Beijing  MIZGAITIS, Mindaugas
# 29213     2008  Beijing       PATRIKEEV, Yuri
# 29214     2008  Beijing         LOPEZ, Mijain
# 29215     2008  Beijing        BAROEV, Khasan
#
# [29216 rows x 3 columns]

# %%
type(oly[['Edition','City','Athlete']])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # Data Input and Validation

# %%
# Using Read csv using Skiprows

oly = pd.read_csv('./data/olympics.csv',skiprows=4)

# %%
oly
# Out:
#           City  Edition      Sport       Discipline               Athlete  \
# 0       Athens     1896   Aquatics         Swimming         HAJOS, Alfred
# 1       Athens     1896   Aquatics         Swimming      HERSCHMANN, Otto
# 2       Athens     1896   Aquatics         Swimming     DRIVAS, Dimitrios
# 3       Athens     1896   Aquatics         Swimming    MALOKINIS, Ioannis
# 4       Athens     1896   Aquatics         Swimming    CHASAPIS, Spiridon
# ...        ...      ...        ...              ...                   ...
# 29211  Beijing     2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko
# 29212  Beijing     2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas
# 29213  Beijing     2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain
# 29215  Beijing     2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan
#
#        NOC Gender                       Event Event_gender   Medal
# ...

# %%
# Using Shape
oly.shape
# Out:
# (29216, 10)

# %%
oly.shape[1]
# Out:
# 10

# %%
# showing first 5rows
oly.head(5)
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
# Showing Last 10 rows
oly.tail(5)
# Out:
#           City  Edition      Sport       Discipline               Athlete  \
# 29211  Beijing     2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko
# 29212  Beijing     2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas
# 29213  Beijing     2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain
# 29215  Beijing     2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan
#
#        NOC Gender       Event Event_gender   Medal
# 29211  GER    Men   84 - 96kg            M  Silver
# 29212  LTU    Men  96 - 120kg            M  Bronze
# 29213  ARM    Men  96 - 120kg            M  Bronze
# 29214  CUB    Men  96 - 120kg            M    Gold
# 29215  RUS    Men  96 - 120kg            M  Silver

# %%
# see data summary 
oly.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29216 entries, 0 to 29215
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   City          29216 non-null  object
#  1   Edition       29216 non-null  int64
#  2   Sport         29216 non-null  object
#  3   Discipline    29216 non-null  object
#  4   Athlete       29216 non-null  object
#  5   NOC           29216 non-null  object
#  6   Gender        29216 non-null  object
#  7   Event         29216 non-null  object
#  8   Event_gender  29216 non-null  object
#  9   Medal         29216 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 2.2+ MB

# %% [markdown]
# # Basic Analysis

# %%
oly
# Out:
#           City  Edition      Sport       Discipline               Athlete  \
# 0       Athens     1896   Aquatics         Swimming         HAJOS, Alfred
# 1       Athens     1896   Aquatics         Swimming      HERSCHMANN, Otto
# 2       Athens     1896   Aquatics         Swimming     DRIVAS, Dimitrios
# 3       Athens     1896   Aquatics         Swimming    MALOKINIS, Ioannis
# 4       Athens     1896   Aquatics         Swimming    CHASAPIS, Spiridon
# ...        ...      ...        ...              ...                   ...
# 29211  Beijing     2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko
# 29212  Beijing     2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas
# 29213  Beijing     2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain
# 29215  Beijing     2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan
#
#        NOC Gender                       Event Event_gender   Medal
# ...

# %% [markdown]
# ### value_counts()

# %%
oly.Edition.value_counts()
# Out:
# 2008    2042
# 2000    2015
# 2004    1998
# 1996    1859
# 1992    1705
# 1988    1546
# 1984    1459
# 1980    1387
# 1976    1305
# 1920    1298
# 1972    1185
# 1968    1031
# 1964    1010
# 1952     889
# 1912     885
# 1956     885
# 1924     884
# 1960     882
# 1936     875
# 1948     814
# 1908     804
# 1928     710
# 1932     615
# 1900     512
# 1904     470
# 1896     151
# Name: Edition, dtype: int64

# %%
oly.Gender.value_counts()
# Out:
# Men      21721
# Women     7495
# Name: Gender, dtype: int64

# %%
#ascending order

oly.Gender.value_counts(ascending= True,dropna=False)
# Out:
# Women     7495
# Men      21721
# Name: Gender, dtype: int64

# %%
# Using dropna = False
# if we check any nulled data we use deopna = False
#by Defaults dropna is true and hide nulled data 
# >>> s = pd.Series([1,2,3, np.nan, 5])
# >>> s.value_counts()
# 5    1
# 3    1
# 2    1
# 1    1

# >>> s.value_counts(dropna = False)

#  5     1
#  3     1
#  2     1
#  1     1
# NaN    1

# %% [markdown]
# ### sort_values()

# %%
ath = oly.Athlete.sort_values()
ath
# Out:
# 651                 AABYE, Edgar
# 2849       AALTONEN, Arvo Ossian
# 2852       AALTONEN, Arvo Ossian
# 7716    AALTONEN, Paavo Johannes
# 7730    AALTONEN, Paavo Johannes
#                   ...
# 603                   ÖSTMO, Ole
# 608                   ÖSTMO, Ole
# 621                   ÖSTMO, Ole
# 596                   ÖSTMO, Ole
# 8051           ÖSTRAND, Per-Olof
# Name: Athlete, Length: 29216, dtype: object

# %%
oly.sort_values(by=['Edition','Athlete'])
# Out:
#           City  Edition       Sport    Discipline  \
# 7       Athens     1896    Aquatics      Swimming
# 82      Athens     1896  Gymnastics   Artistic G.
# 110     Athens     1896  Gymnastics   Artistic G.
# 111     Athens     1896  Gymnastics   Artistic G.
# 48      Athens     1896     Cycling  Cycling Road
# ...        ...      ...         ...           ...
# 28095  Beijing     2008  Equestrian      Dressage
# 28819  Beijing     2008     Sailing       Sailing
# 28977  Beijing     2008   Taekwondo     Taekwondo
# 28387  Beijing     2008  Gymnastics   Rhythmic G.
# 29007  Beijing     2008      Tennis        Tennis
#
#                               Athlete  NOC Gender                 Event  \
# 7                    ANDREOU, Joannis  GRE    Men       1200m freestyle
# 82           ANDRIAKOPOULOS, Nicolaos  GRE    Men         rope climbing
# 110          ANDRIAKOPOULOS, Nicolaos  GRE    Men   team, parallel bars
# ...

# %% [markdown]
# ### Boolean Indexing

# %%
oly.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
#Check who get Gold Medal

oly[oly.Medal == "Gold"]
# Out:
#           City  Edition      Sport       Discipline              Athlete  NOC  \
# 0       Athens     1896   Aquatics         Swimming        HAJOS, Alfred  HUN
# 3       Athens     1896   Aquatics         Swimming   MALOKINIS, Ioannis  GRE
# 6       Athens     1896   Aquatics         Swimming        HAJOS, Alfred  HUN
# 9       Athens     1896   Aquatics         Swimming        NEUMANN, Paul  AUT
# 13      Athens     1896  Athletics        Athletics        BURKE, Thomas  USA
# ...        ...      ...        ...              ...                  ...  ...
# 29199  Beijing     2008  Wrestling  Wrestling Gre-R       GUENOT, Steeve  FRA
# 29203  Beijing     2008  Wrestling  Wrestling Gre-R  KVIRKELIA, Manuchar  GEO
# 29206  Beijing     2008  Wrestling  Wrestling Gre-R     MINGUZZI, Andrea  ITA
# 29210  Beijing     2008  Wrestling  Wrestling Gre-R   KHUSHTOV, Aslanbek  RUS
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R        LOPEZ, Mijain  CUB
#
# ...

# %%
#Cheack only Weman who get Gold Medal

oly[(oly.Medal == "Gold") & (oly.Gender == 'Women')]
# Out:
#            City  Edition          Sport       Discipline  \
# 417       Paris     1900           Golf             Golf
# 641       Paris     1900         Tennis           Tennis
# 649       Paris     1900         Tennis           Tennis
# 710    St Louis     1904        Archery          Archery
# 713    St Louis     1904        Archery          Archery
# ...         ...      ...            ...              ...
# 29134   Beijing     2008  Weightlifting    Weightlifting
# 29147   Beijing     2008      Wrestling  Wrestling Free.
# 29155   Beijing     2008      Wrestling  Wrestling Free.
# 29163   Beijing     2008      Wrestling  Wrestling Free.
# 29171   Beijing     2008      Wrestling  Wrestling Free.
#
#                      Athlete  NOC Gender  \
# 417    ABBOTT, Margaret Ives  USA  Women
# 641        COOPER, Charlotte  GBR  Women
# 649        COOPER, Charlotte  GBR  Women
# 710    HOWELL, Matilda Scott  USA  Women
# 713    HOWELL, Matilda Scott  USA  Women
# ...

# %% [markdown]
# ### String Handling

# %%
oly.Athlete.str.contains('Florence')
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 29211    False
# 29212    False
# 29213    False
# 29214    False
# 29215    False
# Name: Athlete, Length: 29216, dtype: bool

# %%
oly[oly.Athlete.str.contains('Florence')]
# Out:
#                         City  Edition      Sport      Discipline  \
# 1843                  London     1908    Skating  Figure skating
# 1848                  London     1908    Skating  Figure skating
# 4173                   Paris     1924   Aquatics        Swimming
# 8162                Helsinki     1952  Athletics       Athletics
# 9060   Melbourne / Stockholm     1956  Athletics       Athletics
# 10849                  Tokyo     1964  Athletics       Athletics
# 16817            Los Angeles     1984  Athletics       Athletics
# 18287                  Seoul     1988  Athletics       Athletics
# 18305                  Seoul     1988  Athletics       Athletics
# 18347                  Seoul     1988  Athletics       Athletics
# 18374                  Seoul     1988  Athletics       Athletics
#
#                                Athlete  NOC Gender                   Event  \
# 1843                   SYERS, Florence  GBR  Women              individual
# ...

# %% [markdown]
# ### Challenge

# %%
# In which events did Jesse Owens win a medal? 
# Which country has won the most men's gold medals in singles badminton over the years? 
#--Sort the results alphabetically by the player's names.
# Which three countries have won the most medals in recent years(from 1984 to 2008)?
# Display the male gold medal winners for the 100m track and field sprint event over the years.
# -- list the results starting with the most recent and show the olympic city , edition , athelete ,and the country they represent.

# %% [markdown]
# #### In which events did Jesse Owens win a medal?

# %%
oly[oly.Athlete.str.contains('OWENS','Jesse')]
# Out:
#         City  Edition      Sport Discipline       Athlete  NOC Gender  \
# 6427  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
# 6439  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
# 6456  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
# 6523  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
#
#              Event Event_gender Medal
# 6427          100m            M  Gold
# 6439          200m            M  Gold
# 6456  4x100m relay            M  Gold
# 6523     long jump            M  Gold

# %%
oly[oly.Athlete == 'OWENS, Jesse']
# Out:
#         City  Edition      Sport Discipline       Athlete  NOC Gender  \
# 6427  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
# 6439  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
# 6456  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
# 6523  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
#
#              Event Event_gender Medal
# 6427          100m            M  Gold
# 6439          200m            M  Gold
# 6456  4x100m relay            M  Gold
# 6523     long jump            M  Gold

# %% [markdown]
# ####  Which country has won the most men's gold medals in singles badminton over the years? Sort the results alphabetically by the player's names.

# %%
goldmedal = oly[(oly.Medal == "Gold") & (oly.Gender == 'Men') & (oly.Sport == 'Badminton')]

# %%
goldmedal.sort_values(by = 'Athlete')
# Out:
#             City  Edition      Sport Discipline                  Athlete  NOC  \
# 20045  Barcelona     1992  Badminton  Badminton        BUDI KUSUMA, Alan  INA
# 23701     Sydney     2000  Badminton  Badminton            GUNAWAN, Tony  INA
# 25718     Athens     2004  Badminton  Badminton             HA, Tae-Kwon  KOR
# 25734     Athens     2004  Badminton  Badminton          HIDAYAT, Taufik  INA
# 21787    Atlanta     1996  Badminton  Badminton  HOYER-LARSEN, Poul Erik  DEN
# 23717     Sydney     2000  Badminton  Badminton              JI, Xinpeng  CHN
# 27725    Beijing     2008  Badminton  Badminton             KIDO, Markis  INA
# 25719     Athens     2004  Badminton  Badminton           KIM, Dong Moon  KOR
# 21773    Atlanta     1996  Badminton  Badminton           KIM, Dong Moon  KOR
# 20031  Barcelona     1992  Badminton  Badminton            KIM, Moon-Soo  KOR
# 27727    Beijing     2008  Badminton  Badminton             LEE, Yongdae  KOR
# ...

# %% [markdown]
# # Basic Plotting

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Plot Types

# %%
# plot()
# plot(kind = 'line')  # line graph
# plot(kind = 'bar')   # vertical  bar graph
# plot(kind = 'barh')  # horizontal bar graph
# plot(kind = 'pie')   # Circle graphs

# %%
oyl = pd.read_csv('./data/olympics.csv', skiprows=4)
oyl.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %% [markdown]
# ### What were the different sports in the first olympics? Plot them using different graphs.

# %%
fo = oly[oly.Edition == 1896]
fo
# Out:
#        City  Edition          Sport       Discipline  \
# 0    Athens     1896       Aquatics         Swimming
# 1    Athens     1896       Aquatics         Swimming
# 2    Athens     1896       Aquatics         Swimming
# 3    Athens     1896       Aquatics         Swimming
# 4    Athens     1896       Aquatics         Swimming
# ..      ...      ...            ...              ...
# 146  Athens     1896  Weightlifting    Weightlifting
# 147  Athens     1896  Weightlifting    Weightlifting
# 148  Athens     1896      Wrestling  Wrestling Gre-R
# 149  Athens     1896      Wrestling  Wrestling Gre-R
# 150  Athens     1896      Wrestling  Wrestling Gre-R
#
#                       Athlete  NOC Gender                        Event  \
# 0               HAJOS, Alfred  HUN    Men               100m freestyle
# 1            HERSCHMANN, Otto  AUT    Men               100m freestyle
# 2           DRIVAS, Dimitrios  GRE    Men   100m freestyle for sailors
# ...

# %%
fo.Sport.value_counts().plot(kind = 'line');

# %%
fo.Sport.value_counts().plot(kind = 'bar');

# %%
fo.Sport.value_counts().plot(kind = 'barh');

# %%
fo.Sport.value_counts().plot(kind = 'pie');

# %% [markdown]
# ### Plot Colors

# %%
# Plot()
# plot(color = 'red')

# %%
fo.Sport.value_counts().plot(kind = 'barh',color = 'lime');

# %% [markdown]
# ### Figure Size

# %%
# plot(figsize = (width, height)
# plot(kind = 'bar, color = 'yellow' , figsize(5,5))

# %%
fo.Sport.value_counts().plot(color='green',kind = 'bar',figsize=(20,12));

# %% [markdown]
# ### Color Maps

# %%
# Classes of Colormaps
# sequential
# diverging
# qualitative

# %%
fo.Sport.value_counts().plot(kind = 'pie',colormap = 'PiYG');

# %% [markdown]
# # Seaborn

# %%
# countplot()
## seaboard.countplot(x= None, y= None, hue = None, data = None, order = None , hue_order = None, orient = None , color = None , palette = None)
## data : the DataFrame or source of Data
## hue : categorical variables
## order : the sewuence when using categorical levels
## palette : colors to use for the different levels of the hue variable

# %%
import seaborn as sns

# %%
sns.countplot(x = 'Medal', data = oly, hue = 'Gender')
# Out:
# <AxesSubplot:xlabel='Medal', ylabel='count'>

# %% [markdown]
# ## Chalenge -5
#
# ### 1. Plot the number of Medals achieved by the Chinese team (men and women ) in Beijing 2008 using Matplotlib and Seaborn
#
# ### 2. How can you use colormaps to give the data more meaning???
# ### 3. Plot the number of gold ,silver , and bronze medals for each gender .
# ### 4. How can you give the data more meaning ?? Is there anything else you can change to make it more intuitive?

# %% [markdown]
# # Indexing

# %%
type(oly.index)
# Out:
# pandas.core.indexes.range.RangeIndex

# %%
oly.index[100]
# Out:
# 100

# %%
# set_index()
# DataFrame. set_index(keys, drop = True , append = False, inplace = False , verify_integrity = False ) 
# Set the DataFrame using one or more columns
# set_index(keys, inplace = True)

# %% [markdown]
# ### set_index()

# %%
oly.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
oly.set_index('Athlete',inplace=True)

# %%
oly.head()
# Out:
#                       City  Edition     Sport Discipline  NOC Gender  \
# Athlete
# HAJOS, Alfred       Athens     1896  Aquatics   Swimming  HUN    Men
# HERSCHMANN, Otto    Athens     1896  Aquatics   Swimming  AUT    Men
# DRIVAS, Dimitrios   Athens     1896  Aquatics   Swimming  GRE    Men
# MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
# CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                                          Event Event_gender   Medal
# Athlete
# HAJOS, Alfred                   100m freestyle            M    Gold
# HERSCHMANN, Otto                100m freestyle            M  Silver
# DRIVAS, Dimitrios   100m freestyle for sailors            M  Bronze
# MALOKINIS, Ioannis  100m freestyle for sailors            M    Gold
# CHASAPIS, Spiridon  100m freestyle for sailors            M  Silver

# %%
oly.reset_index(inplace=True)

# %%
oly.head()
# Out:
#               Athlete    City  Edition     Sport Discipline  NOC Gender  \
# 0       HAJOS, Alfred  Athens     1896  Aquatics   Swimming  HUN    Men
# 1    HERSCHMANN, Otto  Athens     1896  Aquatics   Swimming  AUT    Men
# 2   DRIVAS, Dimitrios  Athens     1896  Aquatics   Swimming  GRE    Men
# 3  MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
# 4  CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
ath = oly.set_index('Athlete')

# %%
ath
# Out:
#                          City  Edition      Sport       Discipline  NOC  \
# Athlete
# HAJOS, Alfred          Athens     1896   Aquatics         Swimming  HUN
# HERSCHMANN, Otto       Athens     1896   Aquatics         Swimming  AUT
# DRIVAS, Dimitrios      Athens     1896   Aquatics         Swimming  GRE
# MALOKINIS, Ioannis     Athens     1896   Aquatics         Swimming  GRE
# CHASAPIS, Spiridon     Athens     1896   Aquatics         Swimming  GRE
# ...                       ...      ...        ...              ...  ...
# ENGLICH, Mirko        Beijing     2008  Wrestling  Wrestling Gre-R  GER
# MIZGAITIS, Mindaugas  Beijing     2008  Wrestling  Wrestling Gre-R  LTU
# PATRIKEEV, Yuri       Beijing     2008  Wrestling  Wrestling Gre-R  ARM
# LOPEZ, Mijain         Beijing     2008  Wrestling  Wrestling Gre-R  CUB
# BAROEV, Khasan        Beijing     2008  Wrestling  Wrestling Gre-R  RUS
#
#                      Gender                       Event Event_gender   Medal
# Athlete
# ...

# %% [markdown]
# ### reset_index()

# %%
ath.reset_index(inplace=True)
ath.head()
# Out:
#               Athlete    City  Edition     Sport Discipline  NOC Gender  \
# 0       HAJOS, Alfred  Athens     1896  Aquatics   Swimming  HUN    Men
# 1    HERSCHMANN, Otto  Athens     1896  Aquatics   Swimming  AUT    Men
# 2   DRIVAS, Dimitrios  Athens     1896  Aquatics   Swimming  GRE    Men
# 3  MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
# 4  CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %% [markdown]
# ### sort_index()

# %%
ath.head()
# Out:
#               Athlete    City  Edition     Sport Discipline  NOC Gender  \
# 0       HAJOS, Alfred  Athens     1896  Aquatics   Swimming  HUN    Men
# 1    HERSCHMANN, Otto  Athens     1896  Aquatics   Swimming  AUT    Men
# 2   DRIVAS, Dimitrios  Athens     1896  Aquatics   Swimming  GRE    Men
# 3  MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
# 4  CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
ath.set_index('Athlete', inplace=True)

# %%
ath.head()
# Out:
#                       City  Edition     Sport Discipline  NOC Gender  \
# Athlete
# HAJOS, Alfred       Athens     1896  Aquatics   Swimming  HUN    Men
# HERSCHMANN, Otto    Athens     1896  Aquatics   Swimming  AUT    Men
# DRIVAS, Dimitrios   Athens     1896  Aquatics   Swimming  GRE    Men
# MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
# CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                                          Event Event_gender   Medal
# Athlete
# HAJOS, Alfred                   100m freestyle            M    Gold
# HERSCHMANN, Otto                100m freestyle            M  Silver
# DRIVAS, Dimitrios   100m freestyle for sailors            M  Bronze
# MALOKINIS, Ioannis  100m freestyle for sailors            M    Gold
# CHASAPIS, Spiridon  100m freestyle for sailors            M  Silver

# %%
ath.sort_index(inplace=True)

# %%
ath.head()
# Out:
#                              City  Edition       Sport   Discipline  NOC  \
# Athlete
# AABYE, Edgar                Paris     1900  Tug of War   Tug of War  ZZX
# AALTONEN, Arvo Ossian     Antwerp     1920    Aquatics     Swimming  FIN
# AALTONEN, Arvo Ossian     Antwerp     1920    Aquatics     Swimming  FIN
# AALTONEN, Paavo Johannes   London     1948  Gymnastics  Artistic G.  FIN
# AALTONEN, Paavo Johannes   London     1948  Gymnastics  Artistic G.  FIN
#
#                          Gender              Event Event_gender   Medal
# Athlete
# AABYE, Edgar                Men         tug of war            M    Gold
# AALTONEN, Arvo Ossian       Men  200m breaststroke            M  Bronze
# AALTONEN, Arvo Ossian       Men  400m breaststroke            M  Bronze
# AALTONEN, Paavo Johannes    Men       pommel horse            M    Gold
# AALTONEN, Paavo Johannes    Men   team competition            M    Gold

# %%
ath.sort_index(inplace=True,ascending=False)

# %%
ath.head()
# Out:
#                        City  Edition     Sport Discipline  NOC Gender  \
# Athlete
# ÖSTRAND, Per-Olof  Helsinki     1952  Aquatics   Swimming  SWE    Men
# ÖSTMO, Ole            Paris     1900  Shooting   Shooting  NOR    Men
# ÖSTMO, Ole            Paris     1900  Shooting   Shooting  NOR    Men
# ÖSTMO, Ole            Paris     1900  Shooting   Shooting  NOR    Men
# ÖSTMO, Ole            Paris     1900  Shooting   Shooting  NOR    Men
#
#                                            Event Event_gender   Medal
# Athlete
# ÖSTRAND, Per-Olof                 400m freestyle            M  Bronze
# ÖSTMO, Ole         army rifle, 300m, 3 positions            M  Bronze
# ÖSTMO, Ole                      free rifle, team            M  Silver
# ÖSTMO, Ole            army rifle, 300m, standing            M  Silver
# ÖSTMO, Ole               army rifle, 300m, prone            M  Bronze

# %%
oly.head()
# Out:
#               Athlete    City  Edition     Sport Discipline  NOC Gender  \
# 0       HAJOS, Alfred  Athens     1896  Aquatics   Swimming  HUN    Men
# 1    HERSCHMANN, Otto  Athens     1896  Aquatics   Swimming  AUT    Men
# 2   DRIVAS, Dimitrios  Athens     1896  Aquatics   Swimming  GRE    Men
# 3  MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
# 4  CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %% [markdown]
# ### loc[ ] $ iloc[ ]

# %%
oly.set_index('Athlete',inplace=True)

# %%
oly.loc['BOLT, Usain']
# Out:
#                 City  Edition      Sport Discipline  NOC Gender         Event  \
# Athlete
# BOLT, Usain  Beijing     2008  Athletics  Athletics  JAM    Men          100m
# BOLT, Usain  Beijing     2008  Athletics  Athletics  JAM    Men          200m
# BOLT, Usain  Beijing     2008  Athletics  Athletics  JAM    Men  4x100m relay
#
#             Event_gender Medal
# Athlete
# BOLT, Usain            M  Gold
# BOLT, Usain            M  Gold
# BOLT, Usain            M  Gold

# %%
oly.reset_index(inplace=True)

# %%
oly.head()
# Out:
#               Athlete    City  Edition     Sport Discipline  NOC Gender  \
# 0       HAJOS, Alfred  Athens     1896  Aquatics   Swimming  HUN    Men
# 1    HERSCHMANN, Otto  Athens     1896  Aquatics   Swimming  AUT    Men
# 2   DRIVAS, Dimitrios  Athens     1896  Aquatics   Swimming  GRE    Men
# 3  MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
# 4  CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
oly.loc[oly.Athlete == 'BOLT, Usain']
# Out:
#            Athlete     City  Edition      Sport Discipline  NOC Gender  \
# 27552  BOLT, Usain  Beijing     2008  Athletics  Athletics  JAM    Men
# 27570  BOLT, Usain  Beijing     2008  Athletics  Athletics  JAM    Men
# 27603  BOLT, Usain  Beijing     2008  Athletics  Athletics  JAM    Men
#
#               Event Event_gender Medal
# 27552          100m            M  Gold
# 27570          200m            M  Gold
# 27603  4x100m relay            M  Gold

# %%
oly.iloc[[2,124,2390,15000]]
# Out:
#                         Athlete       City  Edition       Sport   Discipline  \
# 2             DRIVAS, Dimitrios     Athens     1896    Aquatics     Swimming
# 124               PAINE, Sumner     Athens     1896    Shooting     Shooting
# 2390         SAASTAMOINEN, Eino  Stockholm     1912  Gymnastics  Artistic G.
# 15000  JENSEN, Poul Richard Hoj   Montreal     1976     Sailing      Sailing
#
#        NOC Gender                                    Event Event_gender  \
# 2      GRE    Men               100m freestyle for sailors            M
# 124    USA    Men                    50m pistol (60 shots)            M
# 2390   FIN    Men                        team, free system            M
# 15000  DEN    Men  fleet/match race keelboat open (Soling)            X
#
#         Medal
# 2      Bronze
# 124      Gold
# 2390   Silver
# 15000    Gold

# %%
# Slicing python 
oly.iloc[1:4]
# Out:
#               Athlete    City  Edition     Sport Discipline  NOC Gender  \
# 1    HERSCHMANN, Otto  Athens     1896  Aquatics   Swimming  AUT    Men
# 2   DRIVAS, Dimitrios  Athens     1896  Aquatics   Swimming  GRE    Men
# 3  MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                         Event Event_gender   Medal
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold

# %% [markdown]
# ## Chalange
# ### 1. Plot the total number of medals awarded at each of the Olympic games throughout history.
# ### 2. Which countries did not win a medal in the 2008 Olympics ? How many countries were there?

# %% [markdown]
# # Groupby

# %%
oly.groupby('Edition')

# %%
type(oly.groupby('Edition'))
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
list(oly.groupby('Edition'))
# Out:
# [(1896,
#                         Athlete    City  Edition          Sport  \
#   0               HAJOS, Alfred  Athens     1896       Aquatics
#   1            HERSCHMANN, Otto  Athens     1896       Aquatics
#   2           DRIVAS, Dimitrios  Athens     1896       Aquatics
#   3          MALOKINIS, Ioannis  Athens     1896       Aquatics
#   4          CHASAPIS, Spiridon  Athens     1896       Aquatics
#   ..                        ...     ...      ...            ...
#   146             JENSEN, Viggo  Athens     1896  Weightlifting
#   147       ELLIOTT, Launceston  Athens     1896  Weightlifting
#   148  CHRISTOPOULOS, Stephanos  Athens     1896      Wrestling
#   149            SCHUMANN, Carl  Athens     1896      Wrestling
#   150          TSITAS, Georgios  Athens     1896      Wrestling
#
#             Discipline  NOC Gender                        Event Event_gender  \
#   0           Swimming  HUN    Men               100m freestyle            M
# ...

# %% [markdown]
# ### Iterate through  a Group

# %%
for group_key, group_value in oly.groupby('Edition'):
    print(group_key)
    print(group_value)
# Out:
# 1896
#                       Athlete    City  Edition          Sport  \
# 0               HAJOS, Alfred  Athens     1896       Aquatics
# 1            HERSCHMANN, Otto  Athens     1896       Aquatics
# 2           DRIVAS, Dimitrios  Athens     1896       Aquatics
# 3          MALOKINIS, Ioannis  Athens     1896       Aquatics
# 4          CHASAPIS, Spiridon  Athens     1896       Aquatics
# ..                        ...     ...      ...            ...
# 146             JENSEN, Viggo  Athens     1896  Weightlifting
# 147       ELLIOTT, Launceston  Athens     1896  Weightlifting
# 148  CHRISTOPOULOS, Stephanos  Athens     1896      Wrestling
# 149            SCHUMANN, Carl  Athens     1896      Wrestling
# 150          TSITAS, Georgios  Athens     1896      Wrestling
#
#           Discipline  NOC Gender                        Event Event_gender  \
# 0           Swimming  HUN    Men               100m freestyle            M
# ...

# %% [markdown]
# ### Groupby Computations

# %%
oly.groupby('Edition').size()
# Out:
# Edition
# 1896     151
# 1900     512
# 1904     470
# 1908     804
# 1912     885
# 1920    1298
# 1924     884
# 1928     710
# 1932     615
# 1936     875
# 1948     814
# 1952     889
# 1956     885
# 1960     882
# 1964    1010
# 1968    1031
# 1972    1185
# 1976    1305
# 1980    1387
# 1984    1459
# 1988    1546
# 1992    1705
# 1996    1859
# 2000    2015
# 2004    1998
# 2008    2042
# dtype: int64

# %% [markdown]
# ### agg([...])

# %%
# oly.groupby(['Edition','NOC','Medal']).agg(['min','max','count'])
oly.groupby(['Edition','NOC','Medal']).agg(['count'])
# Out:
#                    Athlete  City Sport Discipline Gender Event Event_gender
#                      count count count      count  count count        count
# Edition NOC Medal
# 1896    AUS Gold         2     2     2          2      2     2            2
#         AUT Bronze       2     2     2          2      2     2            2
#             Gold         2     2     2          2      2     2            2
#             Silver       1     1     1          1      1     1            1
#         DEN Bronze       3     3     3          3      3     3            3
# ...                    ...   ...   ...        ...    ...   ...          ...
# 2008    UZB Silver       2     2     2          2      2     2            2
#         VEN Bronze       1     1     1          1      1     1            1
#         VIE Silver       1     1     1          1      1     1            1
#         ZIM Gold         1     1     1          1      1     1            1
# ...

# %% [markdown]
# ### agg({:[...]})

# %%
oly.groupby(['Edition','NOC','Medal']).agg({'Edition':['min','max','count']})
# Out:
#                    Edition
#                        min   max count
# Edition NOC Medal
# 1896    AUS Gold      1896  1896     2
#         AUT Bronze    1896  1896     2
#             Gold      1896  1896     2
#             Silver    1896  1896     1
#         DEN Bronze    1896  1896     3
# ...                    ...   ...   ...
# 2008    UZB Silver    2008  2008     2
#         VEN Bronze    2008  2008     1
#         VIE Silver    2008  2008     1
#         ZIM Gold      2008  2008     1
#             Silver    2008  2008     3
#
# [2356 rows x 3 columns]

# %%
oly.loc[oly.Athlete == 'LEWIS, Carl'].groupby('Athlete').agg({'Edition' : ['min','max','count']})
# Out:
#             Edition
#                 min   max count
# Athlete
# LEWIS, Carl    1984  1996    10

# %% [markdown]
# ## Chalange

# %% [markdown]
# ### 1. Using groupby(), plot the total number of medals awarded at each of the Olympic games throughout history.
# ### 2. Create a list showing the total number of medals won for each country over the history of the Olympics . For each counrty , include the year of the first and most recent Olympic medal wins.

# %% [markdown]
# # Reshaping

# %%
mw = oly[(oly.Edition == 2008) & ((oly.Event == '100m') | (oly.Event == '200m'))]

# %%
mw
# Out:
#                         Athlete     City  Edition      Sport Discipline  NOC  \
# 27551               DIX, Walter  Beijing     2008  Athletics  Athletics  USA
# 27552               BOLT, Usain  Beijing     2008  Athletics  Athletics  JAM
# 27553         THOMPSON, Richard  Beijing     2008  Athletics  Athletics  TRI
# 27554        FRASER, Shelly-ann  Beijing     2008  Athletics  Athletics  JAM
# 27555          SIMPSON, Sherone  Beijing     2008  Athletics  Athletics  JAM
# 27556           STEWART, Kerron  Beijing     2008  Athletics  Athletics  JAM
# 27569               DIX, Walter  Beijing     2008  Athletics  Athletics  USA
# 27570               BOLT, Usain  Beijing     2008  Athletics  Athletics  JAM
# 27571           CRAWFORD, Shawn  Beijing     2008  Athletics  Athletics  USA
# 27572           STEWART, Kerron  Beijing     2008  Athletics  Athletics  JAM
# 27573  CAMPBELL-BROWN, Veronica  Beijing     2008  Athletics  Athletics  JAM
# ...

# %%
g = mw.groupby(['NOC','Gender','Discipline','Event']).size()
g
# Out:
# NOC  Gender  Discipline  Event
# JAM  Men     Athletics   100m     1
#                          200m     1
#      Women   Athletics   100m     3
#                          200m     2
# TRI  Men     Athletics   100m     1
# USA  Men     Athletics   100m     1
#                          200m     2
#      Women   Athletics   200m     1
# dtype: int64

# %%
df = g.unstack(['Discipline','Event'])
df
# Out:
# Discipline Athletics
# Event           100m 200m
# NOC Gender
# JAM Men          1.0  1.0
#     Women        3.0  2.0
# TRI Men          1.0  NaN
# USA Men          1.0  2.0
#     Women        NaN  1.0

# %% [markdown]
# ### stack()

# %%
df.stack()
# Out:
# Discipline        Athletics
# NOC Gender Event
# JAM Men    100m         1.0
#            200m         1.0
#     Women  100m         3.0
#            200m         2.0
# TRI Men    100m         1.0
# USA Men    100m         1.0
#            200m         2.0
#     Women  200m         1.0

# %%
df.stack('Event')
# Out:
# Discipline        Athletics
# NOC Gender Event
# JAM Men    100m         1.0
#            200m         1.0
#     Women  100m         3.0
#            200m         2.0
# TRI Men    100m         1.0
# USA Men    100m         1.0
#            200m         2.0
#     Women  200m         1.0

# %% [markdown]
# ### unstack()

# %%
df.unstack()
# Out:
# Discipline Athletics
# Event           100m       200m
# Gender           Men Women  Men Women
# NOC
# JAM              1.0   3.0  1.0   2.0
# TRI              1.0   NaN  NaN   NaN
# USA              1.0   NaN  2.0   1.0

# %%
df.unstack('Gender')
# Out:
# Discipline Athletics
# Event           100m       200m
# Gender           Men Women  Men Women
# NOC
# JAM              1.0   3.0  1.0   2.0
# TRI              1.0   NaN  NaN   NaN
# USA              1.0   NaN  2.0   1.0

# %% [markdown]
# ## Challenge

# %% [markdown]
# ### 1.Plot the number of gold medals won by the US male and female athletes throughout the history of the Ollympics?
# ### 2. Plot the five athletes who have won the most gold medals over the history of the Olympics. When there is a tie , consider the number of silver medals, and then bronxe medals.

# %% [markdown]
# # Data Visualizaitons

# %% [markdown]
# ## Seaborn with heatmaps

# %%
oly.head()
# Out:
#               Athlete    City  Edition     Sport Discipline  NOC Gender  \
# 0       HAJOS, Alfred  Athens     1896  Aquatics   Swimming  HUN    Men
# 1    HERSCHMANN, Otto  Athens     1896  Aquatics   Swimming  AUT    Men
# 2   DRIVAS, Dimitrios  Athens     1896  Aquatics   Swimming  GRE    Men
# 3  MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
# 4  CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
lo = oly[oly.Edition == 2008]

# %%
lo
# Out:
#                     Athlete     City  Edition      Sport       Discipline  \
# 27174        GALPERIN, Gleb  Beijing     2008   Aquatics           Diving
# 27175      MITCHAM, Matthew  Beijing     2008   Aquatics           Diving
# 27176           ZHOU, Luxin  Beijing     2008   Aquatics           Diving
# 27177             WANG, Xin  Beijing     2008   Aquatics           Diving
# 27178          CHEN, Ruolin  Beijing     2008   Aquatics           Diving
# ...                     ...      ...      ...        ...              ...
# 29211        ENGLICH, Mirko  Beijing     2008  Wrestling  Wrestling Gre-R
# 29212  MIZGAITIS, Mindaugas  Beijing     2008  Wrestling  Wrestling Gre-R
# 29213       PATRIKEEV, Yuri  Beijing     2008  Wrestling  Wrestling Gre-R
# 29214         LOPEZ, Mijain  Beijing     2008  Wrestling  Wrestling Gre-R
# 29215        BAROEV, Khasan  Beijing     2008  Wrestling  Wrestling Gre-R
#
#        NOC Gender         Event Event_gender   Medal
# ...

# %%
g = lo.groupby(['NOC','Medal']).size().unstack('Medal', fill_value = 0)
g = g.sort_values(['Gold','Silver','Bronze'],ascending=False)[['Gold','Silver','Bronze']]
g
# Out:
# Medal  Gold  Silver  Bronze
# NOC
# USA     125     109      81
# CHN      74      53      57
# RUS      43      44      56
# GER      42      16      43
# KOR      41      11      26
# ..      ...     ...     ...
# ISR       0       0       1
# MDA       0       0       1
# MRI       0       0       1
# TOG       0       0       1
# VEN       0       0       1
#
# [86 rows x 3 columns]

# %%
sns.heatmap(g)
# Out:
# <AxesSubplot:xlabel='Medal', ylabel='NOC'>

# %%
g = g.transpose()
g
# Out:
# NOC     USA  CHN  RUS  GER  KOR  NED  AUS  GBR  FRA  JPN  ...  VIE  ARM  TPE  \
# Medal                                                     ...
# Gold    125   74   43   42   41   40   31   31   25   23  ...    0    0    0
# Silver  109   53   44   16   11   18   42   25   23   11  ...    1    0    0
# Bronze   81   57   56   43   26    4   76   21   28   17  ...    0    6    4
#
# NOC     AFG  EGY  ISR  MDA  MRI  TOG  VEN
# Medal
# Gold      0    0    0    0    0    0    0
# Silver    0    0    0    0    0    0    0
# Bronze    1    1    1    1    1    1    1
#
# [3 rows x 86 columns]

# %%
plt.figure(figsize=(16,5))
sns.heatmap(g)
# Out:
# <AxesSubplot:xlabel='NOC', ylabel='Medal'>

# %% [markdown]
# ### Create your own Colormap

# %%
g = oly.groupby(['Athlete','Medal']).size().unstack('Medal',fill_value = 0)
g.sort_values(['Gold','Silver','Bronze'],ascending = False)[['Gold','Silver','Bronze']].head().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Athlete'>

# %%
from matplotlib.colors import ListedColormap

# %%
sns.color_palette()
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  (1.0, 0.4980392156862745, 0.054901960784313725),
#  (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
#  (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
#  (0.5803921568627451, 0.403921568627451, 0.7411764705882353),
#  (0.5490196078431373, 0.33725490196078434, 0.29411764705882354),
#  (0.8901960784313725, 0.4666666666666667, 0.7607843137254902),
#  (0.4980392156862745, 0.4980392156862745, 0.4980392156862745),
#  (0.7372549019607844, 0.7411764705882353, 0.13333333333333333),
#  (0.09019607843137255, 0.7450980392156863, 0.8117647058823529)]

# %%
gsb = ['#dbb40c','#c5c9c7','#a87900']
sns.palplot(sns.color_palette(gsb))

# %%
my_gsb = ListedColormap(sns.color_palette(gsb))

# %%
g = oly.groupby(['Athlete','Medal']).size().unstack('Medal',fill_value = 0)
g = g.sort_values(['Gold','Silver','Bronze'],ascending = False)[['Gold','Silver','Bronze']].head()

g.plot(kind='bar',colormap = my_gsb);
