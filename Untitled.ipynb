# %%
import pandas as pd

# %%
oly = pd.read_csv("./data/olympics.csv",skiprows=4)

# %%
oly
# Out:
#           City  Edition      Sport       Discipline               Athlete  \
# 0       Athens     1896   Aquatics         Swimming         HAJOS, Alfred
# 1       Athens     1896   Aquatics         Swimming      HERSCHMANN, Otto
# 2       Athens     1896   Aquatics         Swimming     DRIVAS, Dimitrios
# 3       Athens     1896   Aquatics         Swimming    MALOKINIS, Ioannis
# 4       Athens     1896   Aquatics         Swimming    CHASAPIS, Spiridon
# ...        ...      ...        ...              ...                   ...
# 29211  Beijing     2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko
# 29212  Beijing     2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas
# 29213  Beijing     2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain
# 29215  Beijing     2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan
#
#        NOC Gender                       Event Event_gender   Medal
# ...

# %%
oly.loc[4]
# Out:
# City                                Athens
# Edition                               1896
# Sport                             Aquatics
# Discipline                        Swimming
# Athlete                 CHASAPIS, Spiridon
# NOC                                    GRE
# Gender                                 Men
# Event           100m freestyle for sailors
# Event_gender                             M
# Medal                               Silver
# Name: 4, dtype: object

# %%
oly.iloc[lambda x: x.index % 3 == 0]
# Out:
#        NOC     City  Edition      Sport       Discipline             Athlete  \
# 0      HUN   Athens     1896   Aquatics         Swimming       HAJOS, Alfred
# 3      GRE   Athens     1896   Aquatics         Swimming  MALOKINIS, Ioannis
# 6      HUN   Athens     1896   Aquatics         Swimming       HAJOS, Alfred
# 9      AUT   Athens     1896   Aquatics         Swimming       NEUMANN, Paul
# 12     HUN   Athens     1896  Athletics        Athletics    SZOKOLYI, Alajos
# ...    ...      ...      ...        ...              ...                 ...
# 29202  BUL  Beijing     2008  Wrestling  Wrestling Gre-R     YANAKIEV, Yavor
# 29205  TUR  Beijing     2008  Wrestling  Wrestling Gre-R       AVLUCA, Nazmi
# 29208  KAZ  Beijing     2008  Wrestling  Wrestling Gre-R     MAMBETOV, Asset
# 29211  GER  Beijing     2008  Wrestling  Wrestling Gre-R      ENGLICH, Mirko
# 29214  CUB  Beijing     2008  Wrestling  Wrestling Gre-R       LOPEZ, Mijain
#
# ...

# %%
oly.set_index('NOC', inplace=True)

# %%
oly
# Out:
#         City  Edition      Sport       Discipline               Athlete  \
# NOC
# HUN   Athens     1896   Aquatics         Swimming         HAJOS, Alfred
# AUT   Athens     1896   Aquatics         Swimming      HERSCHMANN, Otto
# GRE   Athens     1896   Aquatics         Swimming     DRIVAS, Dimitrios
# GRE   Athens     1896   Aquatics         Swimming    MALOKINIS, Ioannis
# GRE   Athens     1896   Aquatics         Swimming    CHASAPIS, Spiridon
# ..       ...      ...        ...              ...                   ...
# GER  Beijing     2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko
# LTU  Beijing     2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas
# ARM  Beijing     2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri
# CUB  Beijing     2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain
# RUS  Beijing     2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan
#
#     Gender                       Event Event_gender   Medal
# NOC
# ...

# %%
oly.loc['GRE']
# Out:
#         City  Edition      Sport Discipline                 Athlete Gender  \
# NOC
# GRE   Athens     1896   Aquatics   Swimming       DRIVAS, Dimitrios    Men
# GRE   Athens     1896   Aquatics   Swimming      MALOKINIS, Ioannis    Men
# GRE   Athens     1896   Aquatics   Swimming      CHASAPIS, Spiridon    Men
# GRE   Athens     1896   Aquatics   Swimming   CHOROPHAS, Efstathios    Men
# GRE   Athens     1896   Aquatics   Swimming        ANDREOU, Joannis    Men
# ..       ...      ...        ...        ...                     ...    ...
# GRE  Beijing     2008     Rowing     Rowing    POLYMEROS, Vasileios    Men
# GRE  Beijing     2008    Sailing    Sailing        BEKATOROU, Sofia  Women
# GRE  Beijing     2008    Sailing    Sailing    KRAVARIOTI, Virginia  Women
# GRE  Beijing     2008    Sailing    Sailing     PAPADOPOULOU, Sofia  Women
# GRE  Beijing     2008  Taekwondo  Taekwondo  NIKOLAIDIS, Alexandros    Men
#
#                               Event Event_gender   Medal
# NOC
# ...

# %%
oly.reset_index(inplace=True)

# %%
oly[oly.City == 'Athens']
# Out:
#        NOC    City  Edition      Sport       Discipline               Athlete  \
# 0      HUN  Athens     1896   Aquatics         Swimming         HAJOS, Alfred
# 1      AUT  Athens     1896   Aquatics         Swimming      HERSCHMANN, Otto
# 2      GRE  Athens     1896   Aquatics         Swimming     DRIVAS, Dimitrios
# 3      GRE  Athens     1896   Aquatics         Swimming    MALOKINIS, Ioannis
# 4      GRE  Athens     1896   Aquatics         Swimming    CHASAPIS, Spiridon
# ...    ...     ...      ...        ...              ...                   ...
# 27169  EGY  Athens     2004  Wrestling  Wrestling Gre-R  GABER IBRAHIM, Karam
# 27170  GEO  Athens     2004  Wrestling  Wrestling Gre-R        NOZADZE, Ramaz
# 27171  USA  Athens     2004  Wrestling  Wrestling Gre-R        GARDNER, Rulon
# 27172  RUS  Athens     2004  Wrestling  Wrestling Gre-R        BAROEV, Khasan
# 27173  KAZ  Athens     2004  Wrestling  Wrestling Gre-R   TSURTSUMIA, Georgiy
#
# ...

# %%
oly.iloc[[True]]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-84-e5ec99447319> in <module>
# ----> 1 oly.iloc[[True]]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     877
#     878             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 879             return self._getitem_axis(maybe_callable, axis=axis)
#     880
#     881     def _is_scalar_access(self, key: Tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1481         if com.is_bool_indexer(key):
#    1482             self._validate_key(key, axis)
# -> 1483             return self._getbool_axis(key, axis=axis)
#    1484
#    1485         # a list of integers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getbool_axis(self, key, axis)
# ...
